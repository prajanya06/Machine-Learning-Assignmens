# %% [markdown]
# **MACHINE LEARNING ASSIGNMENT 3**

# %%
import numpy as np
import pandas as pd

customers=pd.read_csv("./AWCustomers.csv")
#part 1(a)
df=pd.DataFrame(customers)
df
# Out:
#        CustomerID Title FirstName  ... TotalChildren YearlyIncome LastUpdated
# 0           21173   NaN      Chad  ...             1        81916  2017-03-06
# 1           13249   NaN      Ryan  ...             2        81076  2017-03-06
# 2           29350   NaN     Julia  ...             0        86387  2017-03-06
# 3           13503   NaN  Theodore  ...             2        61481  2017-03-06
# 4           22803   NaN  Marshall  ...             0        51804  2017-03-06
# ...           ...   ...       ...  ...           ...          ...         ...
# 18356       25414   NaN     Grace  ...             2        52953  2017-03-06
# 18357       11459   NaN     Tasha  ...             0        60992  2017-03-06
# 18358       12160   NaN    Jaclyn  ...             0        51859  2017-03-06
# 18359       14353   NaN      Erin  ...             0        87177  2017-03-06
# 18360       16676   NaN    Amanda  ...             0       136856  2017-03-06
#
# [18361 rows x 24 columns]

# %%
#part 1(b)
newdf=df.filter(['CustomerID','FirstName','LastName','AddressLine1','City','StateProvinceName','CountryRegionName','PostalCode','PhoneNumber','Occupation','Education','HomeOwnerFlag','NumberCarOwned','Gender','MaritalStatus','NumberChildrenAtHome','YearlyIncome'],axis=1)
newdf
# Out:
#        CustomerID FirstName  ... NumberChildrenAtHome YearlyIncome
# 0           21173      Chad  ...                    0        81916
# 1           13249      Ryan  ...                    1        81076
# 2           29350     Julia  ...                    0        86387
# 3           13503  Theodore  ...                    1        61481
# 4           22803  Marshall  ...                    0        51804
# ...           ...       ...  ...                  ...          ...
# 18356       25414     Grace  ...                    0        52953
# 18357       11459     Tasha  ...                    0        60992
# 18358       12160    Jaclyn  ...                    0        51859
# 18359       14353      Erin  ...                    0        87177
# 18360       16676    Amanda  ...                    0       136856
#
# [18361 rows x 16 columns]

# %% [markdown]
# PART 1(C)
#
# HomeOwnerFlag --> Nominal
#
# Gender --> Nominal
#
# HomeOwnerStatus --> Nominal
#
# MaritalStatus --> Nominal
#
# NumberChildrenAtHome --> Ordinal
#
# YearlyIncome --> Continous

# %%
#part 2
newdf.describe()
# Out:
#          CustomerID  HomeOwnerFlag  NumberChildrenAtHome   YearlyIncome
# count  18361.000000   18361.000000          18361.000000   18361.000000
# mean   20241.987092       0.610588              0.338162   72754.779642
# std     5336.332731       0.487630              0.568957   30686.014313
# min    11000.000000       0.000000              0.000000   25435.000000
# 25%    15621.000000       0.000000              0.000000   53312.000000
# 50%    20248.000000       1.000000              0.000000   61851.000000
# 75%    24863.000000       1.000000              1.000000   87410.000000
# max    29483.000000       1.000000              3.000000  139115.000000

# %%
#zero nulls in data set
newdf.isnull().sum()
# Out:
# CustomerID              0
# FirstName               0
# LastName                0
# AddressLine1            0
# City                    0
# StateProvinceName       0
# CountryRegionName       0
# PostalCode              0
# PhoneNumber             0
# Occupation              0
# Education               0
# HomeOwnerFlag           0
# Gender                  0
# MaritalStatus           0
# NumberChildrenAtHome    0
# YearlyIncome            0
# dtype: int64

# %%
#normalization
newdf['NewIncome']=(newdf['YearlyIncome']-newdf['YearlyIncome'].min())/(newdf['YearlyIncome'].max()-newdf['YearlyIncome'].min())
newdf
# Out:
#        CustomerID FirstName  ... YearlyIncome NewIncome
# 0           21173      Chad  ...        81916  0.496842
# 1           13249      Ryan  ...        81076  0.489453
# 2           29350     Julia  ...        86387  0.536172
# 3           13503  Theodore  ...        61481  0.317083
# 4           22803  Marshall  ...        51804  0.231958
# ...           ...       ...  ...          ...       ...
# 18356       25414     Grace  ...        52953  0.242065
# 18357       11459     Tasha  ...        60992  0.312781
# 18358       12160    Jaclyn  ...        51859  0.232442
# 18359       14353      Erin  ...        87177  0.543121
# 18360       16676    Amanda  ...       136856  0.980128
#
# [18361 rows x 17 columns]

# %%
len(newdf['CountryRegionName'].unique())
# Out:
# 6

# %%
#binning
import matplotlib.pyplot as plt

Nation=newdf['CountryRegionName']
plt.hist(Nation, bins=6)
plt.show()

# %%
#binning wrt children's population at home
print(newdf['NumberChildrenAtHome'].unique())
plt.hist(newdf['NumberChildrenAtHome'], bins=4)
# Out:
# [0 1 2 3]
# (array([13038.,  4468.,   824.,    31.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <a list of 4 Patch objects>)

# %%
#binarization
newdf['YearlyIncome'].mean()
from sklearn.preprocessing import Binarizer
salary = newdf.iloc[:, 15].values
salary
y = salary
y = y.reshape(1,-1)
bin = Binarizer(7300)
x = bin.fit_transform(y) 
x
# Out:
# array([[1, 1, 1, ..., 1, 1, 1]])

# %% [markdown]
# ***ASSIGNMENT 3 END***
